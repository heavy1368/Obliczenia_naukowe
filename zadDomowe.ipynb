# %% [markdown]
# <a href="https://colab.research.google.com/github/heavy1368/Obliczenia_naukowe/blob/main/zadDomowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #*To jest tytuł*
# ##Pierwsza sekcja

# %%
imie = input("Jak masz na imię:")
print("Czejsc ", imie)
# Out:
# Jak masz na imię:Michal
# Czejsc  Michal

# %% [markdown]
# ### Druga sekcja

# %% [markdown]
# #### Trzecia sekcja ![tapeciarnia.pl-tapeta-pomost-nad-jeziorem-w-gorach.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##### Czwarta sekcja
